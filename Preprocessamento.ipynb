# %%
import pandas as pd
import seaborn as sb
from sklearn import preprocessing


# %matplotlib inline 

df = pd.read_csv("cons2015-2018.csv")
# df = pd.read_csv("iris.csv")

# scaler = preprocessing.StandardScaler.fit(df[['COMARCA']])
# df['COMARCA'] = scaler.transform(df[['COMARCA']])

df['COMARCA'].describe()
# Out:
# count       7283
# unique       154
# top       RECIFE
# freq        1594
# Name: COMARCA, dtype: object

# %%
# sb.pairplot(df,hue="species")
for col in  df.columns[0:4]:
    df[col] = df[col].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-a181cb2e7538> in <module>()
#       1 # sb.pairplot(df,hue="species")
#       2 for col in  df.columns[0:4]:
# ----> 3     df[col] = df[col].astype(float)
#
# /home/marlon/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# /home/marlon/anaconda2/lib/python2.7/site-packages/pandas/core/internals/managers.pyc in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# ...

# %%
df
# Out:
#                         Nº AÇÃO  \
# 0      002791-69.2015.8.17.0000
# 1     0022055-78.2018.8.17.2001
# 2     0049167-85.2014.8.17.8201
# 3                     0493238-1
# 4                      391/2018
# 5                     0410276-5
# 6                           NaN
# 7     0004449-06.2016.8.17.2810
# 8     0004449-06.2016.8.17.2810
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13    0001094-44.2016.8.17.1110
# 14    0010634-85.2017.8.17.2370
# 15    0008336-29.2018.8.17.2001
# 16    0000812-49.2016.8.17.2001
# 17    0806816-56.2016.4.05.8300
# 18    0000710-27.2016.8.17.2001
# 19          TOMBO Nº 15556/2017
# 20    0500284-47.2017.4.05.8308
# 21    0046582-65.2016.8.17.2001
# 22    0045254-56.2018.8.17.8201
# 23    0000316-66.2016.8.17.0660
# 24    0800469-80.2016.4.05.8308
# 25    0807837-38.2016.04.5.0000
# 26    0002938-22.2016.8.17.0110
# 27    0001089-70.2017.8.17.2570
# ...
