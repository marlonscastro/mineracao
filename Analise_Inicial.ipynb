# %%
# Testes iniciais

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import preprocessing

# %matplotlib inline 

df = pd.read_csv("cons2015-2018.csv")

df.head(3)
# Out:
#                      Nº AÇÃO       MEDICAMENTO  Nº M  \
# 0   002791-69.2015.8.17.0000      LENALIDOMIDA   1.0
# 1  0022055-78.2018.8.17.2001  INTERNAMENTO UTI   1.0
# 2  0049167-85.2014.8.17.8201       CINACALCETE   1.0
#
#                                PATOLOGIA  \
# 0               C90.0 - MIELOMA MÚLTIPLO
# 1                          NÃO INFORMADO
# 2  N18.0 - DOENÇA RENAL EM ESTÁDIO FINAL
#
#                                 PRESCRITOR                         UNIDADE  \
# 0  RENATA LYGIA VIEIRA VASCONCELOS PE15631  HBL - HOSPITAL BARÃO DE LUCENA
# 1                            NÃO INFORMADO                   NÃO INFORMADO
# 2                            NÃO INFORMADO                            IMIP
#
#           ORIGEM                           JUIZ COMARCA  \
# 0            SUS  JORGE AMÉRICO PEREIRA DE LIRA    TJPE
# 1  NÃO INFORMADO            MARIZA SILVA BORGES  RECIFE
# 2   FILANTRÓPICO       ROBERTO CARNEIRO PEDROSA   JEFPC
#
# ...

# %%
# df.count()

# %%
df.groupby(['COMARCA','DEFERIDA'])['JUIZ'].size()

# x = df.groupby(['COMARCA'])['DEFERIDA'].size()
# Out:
# COMARCA                 DEFERIDA
# ABREU E LIMA            SIM          43
# AFOGADOS DA INGAZEIRA   SIM          60
# AFRÂNIO                 SIM           2
# AGRESTINA               NÃO           2
#                         SIM           5
# AGUA PRETA              SIM           3
# ALAGOINHA               SIM          15
# ALIANÇA                 NÃO           4
#                         SIM           8
# ALTINHO                 SIM           8
# AMARAJI                 SIM           2
# ANGELIM                 SIM           3
# ARARIPINA               NÃO           1
#                         SIM           4
# ARCOVERDE               NÃO          15
#                         SIM          85
# BARREIROS               SIM          22
# BELO JARDIM             NÃO           1
#                         SIM          20
# BELÉM DE MARIA          SIM           2
# BELÉM DO SÃO FRANCISCO  SIM           8
# BETÂNIA                 NÃO           1
# ...

# %%
x = df[df.COMARCA == "RECIFE"]
x
# Out:
#                         Nº AÇÃO                         MEDICAMENTO  Nº M  \
# 1     0022055-78.2018.8.17.2001                    INTERNAMENTO UTI   1.0
# 4                      391/2018            TRANSFERÊNCIA HOSPITALAR   1.0
# 15    0008336-29.2018.8.17.2001                    INTERNAMENTO UTI   1.0
# 16    0000812-49.2016.8.17.2001                    INTERNAMENTO UTI   1.0
# 18    0000710-27.2016.8.17.2001                    INTERNAMENTO UTI   1.0
# 19          TOMBO Nº 15556/2017                    INTERNAMENTO UTI   1.0
# 21    0046582-65.2016.8.17.2001                           BOSENTANA   1.0
# 27    0001089-70.2017.8.17.2570                        ENZALUTAMIDA   1.0
# 28    0050430-26.2017.8.17.2001                        LENALIDOMIDA   1.0
# 29    0008526-89.2018.8.17.2001                          FILGRASTIM   1.0
# 30    0070551-75.2017.8.17.2001                    INTERNAMENTO UTI   1.0
# 35          TOMBO Nº 12391/2016                         ABIRATERONA   1.0
# ...
